# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from sklearn import linear_model

# %%
url="https://archive.ics.uci.edu/ml/machine-learning-databases/event-detection/CalIt2.data"
data = pd.read_csv(url, sep=",", header = None)
data.columns = ["type", "date", "time", "count"]
print data.head()
print '\n Data Types:'
print data.dtypes
print data.index
# Out:
#    type      date      time  count
# 0     7  07/24/05  00:00:00      0
# 1     9  07/24/05  00:00:00      0
# 2     7  07/24/05  00:30:00      1
# 3     9  07/24/05  00:30:00      0
# 4     7  07/24/05  01:00:00      0
#
#  Data Types:
# type      int64
# date     object
# time     object
# count     int64
# dtype: object
# RangeIndex(start=0, stop=10080, step=1)

# %%
data = pd.read_csv(url, sep=",", header = None, names = ("type", "date", "time", "count"), parse_dates={'datetime': ['date', 'time']}, index_col='datetime')
print data.head()
print 'Data Types:'
print data.dtypes
print data.index
# Out:
#                      type  count
# datetime
# 2005-07-24 00:00:00     7      0
# 2005-07-24 00:00:00     9      0
# 2005-07-24 00:30:00     7      1
# 2005-07-24 00:30:00     9      0
# 2005-07-24 01:00:00     7      0
# Data Types:
# type     int64
# count    int64
# dtype: object
# DatetimeIndex(['2005-07-24 00:00:00', '2005-07-24 00:00:00',
#                '2005-07-24 00:30:00', '2005-07-24 00:30:00',
#                '2005-07-24 01:00:00', '2005-07-24 01:00:00',
#                '2005-07-24 01:30:00', '2005-07-24 01:30:00',
#                '2005-07-24 02:00:00', '2005-07-24 02:00:00',
#                ...
#                '2005-11-05 21:30:00', '2005-11-05 21:30:00',
#                '2005-11-05 22:00:00', '2005-11-05 22:00:00',
#                '2005-11-05 22:30:00', '2005-11-05 22:30:00',
#                '2005-11-05 23:00:00', '2005-11-05 23:00:00',
#                '2005-11-05 23:30:00', '2005-11-05 23:30:00'],
#               dtype='datetime64[ns]', name=u'datetime', length=10080, freq=None)

# %%
# Calculating the number of people in the building at different point of time in a day.
OUTFLOW_ID = 7
ppl_inside = 0
y_arr = np.zeros((0, 2))
i = 0;
for index, row in data.iterrows():
    if row['type'] == OUTFLOW_ID:
        ppl_inside -= row['count']
    else:
        ppl_inside += row['count'] 
    if(i % 2 != 0):
        y_arr = np.vstack((y_arr, [index, ppl_inside]))
    i+=1;
    
plt.plot(y_arr[:,0], y_arr[:,1])
plt.show()

# %%
ts = data['count']
ts.head(10)
# Out:
# datetime
# 2005-07-24 00:00:00    0
# 2005-07-24 00:00:00    0
# 2005-07-24 00:30:00    1
# 2005-07-24 00:30:00    0
# 2005-07-24 01:00:00    0
# 2005-07-24 01:00:00    0
# 2005-07-24 01:30:00    0
# 2005-07-24 01:30:00    0
# 2005-07-24 02:00:00    0
# 2005-07-24 02:00:00    0
# Name: count, dtype: int64

# %%
plt.plot(ts)
plt.show()

# %%
ys = np.array([ts[i] for i in  xrange(0,len(ts))])
EMOV_n = pd.Series(ys).ewm(com=2).mean()
print EMOV_n
# Out:
# 0        0.000000
# 1        0.000000
# 2        0.473684
# 3        0.276923
# 4        0.170616
# 5        0.108271
# 6        0.069937
# 7        0.045678
# 8        0.030045
# 9        0.019854
# 10       0.687622
# 11       0.456635
# 12       0.303637
# 13       0.202077
# 14       0.134564
# 15       0.089641
# 16       0.059730
# 17       0.039807
# 18       0.026532
# 19       0.017685
# 20       0.011789
# 21       0.007859
# 22       0.005239
# 23       0.003493
# 24       0.002328
# 25       0.001552
# 26       0.001035
# 27       0.000690
# 28       0.000460
# 29       0.000307
#            ...
# 10050    0.536848
# 10051    1.024565
# 10052    1.016377
# 10053    0.677584
# 10054    0.451723
# 10055    0.301149
# 10056    0.534099
# 10057    0.356066
# 10058    0.237377
# 10059    0.158252
# 10060    0.772168
# 10061    0.514778
# 10062    0.676519
# 10063    0.451013
# 10064    0.634008
# 10065    0.422672
# 10066    0.948448
# 10067    0.632299
# 10068    0.421533
# 10069    0.281022
# 10070    0.187348
# 10071    0.124899
# 10072    1.083266
# 10073    0.722177
# 10074    0.481451
# 10075    0.320968
# 10076    0.213978
# 10077    0.142652
# 10078    0.428435
# 10079    0.285623
# Length: 10080, dtype: float64

# %%
Xs = np.ones(len(ys))
print np.shape(Xs)
# Out:
# (10080,)

# %%
print np.shape(np.hstack((Xs, EMOV_n)))
# print np.shape(np.vstack())
print len(EMOV_n)
# Out:
# (20160,)
# 10080

# %%
EMOV_n = EMOV_n.reshape(-1,1)
ys = ys.reshape(-1,1)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.

# %%
# LINEAR Regression
clf = linear_model.LinearRegression()
clf.fit(EMOV_n, ys)
print clf.coef_
print np.mean(clf.predict(EMOV_n) - ys)
# Out:
# [[ 1.05286132]]
# 2.24159315448e-16

# %%
# RIDGE Regression
reg = linear_model.Ridge (alpha = 0.1)
reg.fit (EMOV_n, ys)
print reg.coef_
print np.mean(reg.predict(EMOV_n) - ys)
# Out:
# [[ 1.05286098]]
# 1.2547282437e-16

# %%
# Finding the week of the day
weeknames = []
for i in xrange (0, len(y_arr)):
    weeknames.append(y_arr[i, 0].weekday_name)
    weeknames.append(y_arr[i, 0].weekday_name)
    
calendar_days = []
for i in xrange (0, len(y_arr)):
    calendar_days.append(y_arr[i, 0].days_in_month)
    calendar_days.append(y_arr[i, 0].days_in_month)
    
month_numbers = []
for i in xrange (0, len(y_arr)):
    month_numbers.append(y_arr[i, 0].month)
    month_numbers.append(y_arr[i, 0].month)


hours = []
for i in xrange (0, len(y_arr)):
    hours.append(y_arr[i, 0].hour)
    hours.append(y_arr[i, 0].hour)

mins = []
for i in xrange (0, len(y_arr)):
    mins.append(y_arr[i, 0].minute)
    mins.append(y_arr[i, 0].minute)


weeknames = np.array(weeknames).reshape(-1,1)
calendar_days = np.array(calendar_days).reshape(-1,1)
month_numbers = np.array(month_numbers).reshape(-1,1)
hours = np.array(hours).reshape(-1,1)
mins = np.array(mins).reshape(-1,1)
Xtrain = EMOV_n
#Xtrain = np.hstack((Xtrain, weeknames))
Xtrain = np.hstack((Xtrain, calendar_days))
Xtrain = np.hstack((Xtrain, month_numbers))
Xtrain = np.hstack((Xtrain, hours))
Xtrain = np.hstack((Xtrain, mins))

# %%
# LINEAR Regression
clf = linear_model.LinearRegression()
clf.fit(Xtrain, ys)
print clf.coef_
print np.mean(clf.predict(Xtrain) - ys)
# Out:
# [[ 1.06753678 -0.00452577 -0.03116396 -0.04700083 -0.00643491]]
# -3.45120757369e-15

# %%
# RIDGE Regression
reg = linear_model.Ridge (alpha = 0.1)
reg.fit (Xtrain, ys)
print reg.coef_
print np.mean(reg.predict(Xtrain) - ys)
# Out:
# [[ 1.06753641 -0.00452537 -0.03116346 -0.04700075 -0.00643491]]
# -4.41128615118e-15

# %%
#Calculating holiday or not
from pandas.tseries.holiday import USFederalHolidayCalendar

df = pd.DataFrame()
#df['Date'] = y_arr[:,0]
df['Date'] = pd.date_range(start='2005-07-24', end='2005-11-05')

# df['Date'] = pd.date_range(start='2005-07-24', end='2005-11-05')
holiday_cal = USFederalHolidayCalendar()
holidays = holiday_cal.holidays(start='2005-07-24', end='2005-11-05')

df['Holiday'] = df['Date'].isin(holidays)
print df

# h_df = []
# for i in xrange(0, len(y_arr)):
#     print type(y_arr[i,0])
#     h_df.append(y_arr[i,0].isin(holidays))
# df['Holiday'] = h_df
# print df
# Out:
#           Date  Holiday
# 0   2005-07-24    False
# 1   2005-07-25    False
# 2   2005-07-26    False
# 3   2005-07-27    False
# 4   2005-07-28    False
# 5   2005-07-29    False
# 6   2005-07-30    False
# 7   2005-07-31    False
# 8   2005-08-01    False
# 9   2005-08-02    False
# 10  2005-08-03    False
# 11  2005-08-04    False
# 12  2005-08-05    False
# 13  2005-08-06    False
# 14  2005-08-07    False
# 15  2005-08-08    False
# 16  2005-08-09    False
# 17  2005-08-10    False
# 18  2005-08-11    False
# 19  2005-08-12    False
# 20  2005-08-13    False
# 21  2005-08-14    False
# 22  2005-08-15    False
# 23  2005-08-16    False
# 24  2005-08-17    False
# 25  2005-08-18    False
# 26  2005-08-19    False
# 27  2005-08-20    False
# 28  2005-08-21    False
# 29  2005-08-22    False
# ..         ...      ...
# 75  2005-10-07    False
# 76  2005-10-08    False
# 77  2005-10-09    False
# 78  2005-10-10     True
# 79  2005-10-11    False
# 80  2005-10-12    False
# 81  2005-10-13    False
# 82  2005-10-14    False
# 83  2005-10-15    False
# 84  2005-10-16    False
# 85  2005-10-17    False
# 86  2005-10-18    False
# 87  2005-10-19    False
# 88  2005-10-20    False
# 89  2005-10-21    False
# 90  2005-10-22    False
# 91  2005-10-23    False
# 92  2005-10-24    False
# 93  2005-10-25    False
# 94  2005-10-26    False
# 95  2005-10-27    False
# 96  2005-10-28    False
# 97  2005-10-29    False
# 98  2005-10-30    False
# 99  2005-10-31    False
# 100 2005-11-01    False
# 101 2005-11-02    False
# 102 2005-11-03    False
# 103 2005-11-04    False
# 104 2005-11-05    False
#
# [105 rows x 2 columns]

# %%
data = pd.read_csv('prediction_data.csv', sep=",", parse_dates=[0], index_col = [0])
print data.head()
print '\n Data Types:'
print data.dtypes
print data.index
# Out:
#                       PandaExpress   Anthill Pub & Grille
# Time
# 2017-06-15 08:00:00               1                     0
# 2017-06-15 08:30:00               2                     0
# 2017-06-15 09:00:00               1                     0
# 2017-06-15 09:15:00               3                     0
# 2017-06-15 09:30:00               5                     0
#
#  Data Types:
#  PandaExpress           int64
# Anthill Pub & Grille    int64
# dtype: object
# DatetimeIndex(['2017-06-15 08:00:00', '2017-06-15 08:30:00',
#                '2017-06-15 09:00:00', '2017-06-15 09:15:00',
#                '2017-06-15 09:30:00', '2017-06-15 09:45:00',
#                '2017-06-15 10:00:00', '2017-06-15 10:15:00',
#                '2017-06-15 10:30:00', '2017-06-15 10:45:00',
#                '2017-06-15 11:00:00', '2017-06-15 11:15:00',
#                '2017-06-15 11:30:00', '2017-06-15 11:45:00',
#                '2017-06-15 12:00:00', '2017-06-15 12:15:00',
#                '2017-06-15 12:30:00', '2017-06-15 12:45:00',
#                '2017-06-15 13:00:00', '2017-06-15 13:15:00',
#                '2017-06-15 13:30:00', '2017-06-15 13:45:00',
#                '2017-06-15 14:00:00', '2017-06-15 14:15:00',
#                '2017-06-15 14:30:00', '2017-06-15 14:45:00',
#                '2017-06-15 15:00:00', '2017-06-15 15:15:00',
#                '2017-06-15 15:30:00', '2017-06-15 15:45:00',
#                '2017-06-15 16:00:00', '2017-06-15 16:15:00',
#                '2017-06-15 16:30:00', '2017-06-15 16:45:00',
#                '2017-06-15 17:00:00', '2017-06-15 17:15:00',
#                '2017-06-15 17:30:00', '2017-06-15 17:45:00',
#                '2017-06-15 18:00:00', '2017-06-15 18:15:00',
#                '2017-06-15 18:30:00', '2017-06-15 18:45:00',
#                '2017-06-15 19:00:00', '2017-06-15 19:15:00',
#                '2017-06-15 19:30:00', '2017-06-15 19:45:00',
#                '2017-06-15 20:00:00', '2017-06-15 20:15:00',
#                '2017-06-15 20:30:00', '2017-06-15 20:45:00',
#                '2017-06-15 21:00:00', '2017-06-15 21:15:00',
#                '2017-06-15 21:30:00', '2017-06-15 21:45:00',
#                '2017-06-15 22:00:00', '2017-06-15 22:15:00',
#                '2017-06-15 22:30:00', '2017-06-15 22:45:00',
#                '2017-06-15 23:00:00', '2017-06-15 23:15:00',
#                '2017-06-15 23:30:00', '2017-06-15 23:45:00',
#                '2017-06-15 00:00:00'],
#               dtype='datetime64[ns]', name=u'Time ', freq=None)

# %%
data.plot.bar()
plt.title('Prediction of occupancy at different times of the day')
plt.xlabel('Time of the day')
plt.ylabel('Occpancy percentage')
plt.show('prediction')

# %%
data = pd.read_csv('prediction_data.csv', sep=",", parse_dates=[0])
print data.head()

clf = linear_model.LinearRegression()
clf.fit(data.ix[:, 2], data.ix[:, 1])
# Out:
#                 Time    PandaExpress   Anthill Pub & Grille
# 0 2017-06-15 08:00:00               1                     0
# 1 2017-06-15 08:30:00               2                     0
# 2 2017-06-15 09:00:00               1                     0
# 3 2017-06-15 09:15:00               3                     0
# 4 2017-06-15 09:30:00               5                     0
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-0ffbe2ea1c2e> in <module>()
#       3
#       4 clf = linear_model.LinearRegression()
# ----> 5 clf.fit(data.ix[:, 2], data.ix[:, 1])
#
# /usr/local/lib/python2.7/dist-packages/sklearn/linear_model/base.pyc in fit(self, X, y, sample_weight)
#     510         n_jobs_ = self.n_jobs
#     511         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 512                          y_numeric=True, multi_output=True)
#     513
#     514         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     529         y = y.astype(np.float64)
#     530
# --> 531     check_consistent_length(X, y)
#     532
#     533     return X, y
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.pyc in check_consistent_length(*arrays)
#     179     if len(uniques) > 1:
#     180         raise ValueError("Found input variables with inconsistent numbers of"
# --> 181                          " samples: %r" % [int(l) for l in lengths])
#     182
#     183
#
# ValueError: Found input variables with inconsistent numbers of samples: [1, 63]
